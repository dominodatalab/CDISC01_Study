# %%
from domino.data_sources import DataSourceClient

# instantiate a client and fetch the datasource instance
object_store = DataSourceClient().get_datasource("S3")

# list objects available in the datasource
objects = object_store.list_objects()

## get content as binary
# content = object_store.get("key")

## download content to file
# object_store.download_file("key", "./path/to/local/file")

## Download content to file object
# f = io.BytesIO()
# object_store.download_fileobj("key", f)

# %%
objects
# Out:
# [_Object(key='Test data - GT_alphanumeric.csv'),
#  _Object(key='Test data - Predictionnew1.csv'),
#  _Object(key='Training-missing_at_random-Training data.csv'),
#  _Object(key='drift_divorce.csv'),
#  _Object(key='drift_ground_truth_divorce.csv'),
#  _Object(key='driver_stats.parquet'),
#  _Object(key='dsp_test_dir/divorce.csv'),
#  _Object(key='dsp_test_dir/drift_divorce.csv'),
#  _Object(key='dsp_test_dir/drift_ground_truth_divorce.csv'),
#  _Object(key='dsp_test_dir/drift_ground_truth_divorce1.csv'),
#  _Object(key='dsp_test_dir/drift_ground_truth_divorce2.csv'),
#  _Object(key='dsp_test_dir/model_monitor_train_divorce.csv'),
#  _Object(key='dsp_test_dir/prototype_pred.csv'),
#  _Object(key='dsp_test_dir/remedy_pred.csv'),
#  _Object(key='dsp_test_dir/train_divorce.csv'),
#  _Object(key='inactive/Andrews_files/actual_house_prices.csv'),
#  _Object(key='inactive/Andrews_files/gt_actual_pred.csv'),
#  _Object(key='inactive/Andrews_files/housing-pred-data.csv'),
#  _Object(key='inactive/Andrews_files/kc_house_data.csv'),
#  _Object(key='inactive/C22760_prediction_11.csv'),
#  _Object(key='inactive/C22760_prediction_2.csv'),
#  _Object(key='inactive/archive/config.json'),
#  _Object(key='inactive/archive/modelcard.json'),
#  _Object(key='inactive/archive/spiece.model'),
#  _Object(key='inactive/archive/tf_model.h5'),
#  _Object(key='inactive/aug_data/masks/00004_3.png'),
#  _Object(key='inactive/aug_data/masks/00006_1.png'),
#  _Object(key='inactive/aug_data/masks/00020_2.png'),
#  _Object(key='inactive/aug_data/masks/00022_0.png'),
#  _Object(key='inactive/aug_data/masks/00041_3.png'),
#  _Object(key='inactive/aug_data/masks/00043_1.png'),
#  _Object(key='inactive/aug_data/masks/00058_2.png'),
#  _Object(key='inactive/aug_data/masks/00065_2.png'),
#  _Object(key='inactive/aug_data/masks/00067_0.png'),
#  _Object(key='inactive/aug_data/masks/00098_2.png'),
#  _Object(key='inactive/aug_data/masks/00106_4.png'),
#  _Object(key='inactive/aug_data/masks/00119_3.png'),
#  _Object(key='inactive/aug_data/masks/00143_4.png'),
#  _Object(key='inactive/aug_data/masks/00178_2.png'),
#  _Object(key='inactive/aug_data/masks/00185_2.png'),
#  _Object(key='inactive/aug_data/masks/00187_0.png'),
#  _Object(key='inactive/aug_data/masks/00203_0.png'),
#  _Object(key='inactive/aug_data/masks/00207_4.png'),
#  _Object(key='inactive/aug_data/masks/00218_3.png'),
#  _Object(key='inactive/aug_data/masks/00225_3.png'),
#  _Object(key='inactive/aug_data/masks/00242_4.png'),
#  _Object(key='inactive/aug_data/masks/00246_0.png'),
#  _Object(key='inactive/aug_data/masks/00260_3.png'),
#  _Object(key='inactive/aug_data/masks/00279_2.png'),
#  _Object(key='inactive/aug_data/masks/00284_2.png'),
#  _Object(key='inactive/aug_data/masks/00286_0.png'),
#  _Object(key='inactive/aug_data/masks/00305_3.png'),
#  _Object(key='inactive/aug_data/masks/00307_1.png'),
#  _Object(key='inactive/aug_data/masks/00321_2.png'),
#  _Object(key='inactive/aug_data/masks/00323_0.png'),
#  _Object(key='inactive/aug_data/masks/00327_4.png'),
#  _Object(key='inactive/aug_data/masks/00340_3.png'),
#  _Object(key='inactive/aug_data/masks/00342_1.png'),
#  _Object(key='inactive/aug_data/masks/00362_4.png'),
#  _Object(key='inactive/aug_data/masks/00364_2.png'),
#  _Object(key='inactive/aug_data/masks/00366_0.png'),
#  _Object(key='inactive/aug_data/masks/00382_1.png'),
#  _Object(key='inactive/aug_data/masks/00428_3.png'),
#  _Object(key='inactive/aug_data/masks/00431_2.png'),
#  _Object(key='inactive/aug_data/masks/00449_2.png'),
#  _Object(key='inactive/aug_data/masks/00472_4.png'),
#  _Object(key='inactive/aug_data/masks/00489_2.png'),
#  _Object(key='inactive/aug_data/masks/00490_3.png'),
#  _Object(key='inactive/aug_data/masks/00492_1.png'),
#  _Object(key='inactive/aug_data/masks/00508_3.png'),
#  _Object(key='inactive/aug_data/masks/00511_2.png'),
#  _Object(key='inactive/aug_data/masks/00513_0.png'),
#  _Object(key='inactive/aug_data/masks/00537_1.png'),
#  _Object(key='inactive/aug_data/masks/00554_2.png'),
#  _Object(key='inactive/aug_data/masks/00556_0.png'),
#  _Object(key='inactive/aug_data/masks/00572_1.png'),
#  _Object(key='inactive/carssas7.csv'),
#  _Object(key='inactive/demo-ford.txt'),
#  _Object(key='inactive/diabetes.csv'),
#  _Object(key='inactive/diabetes_changed.csv'),
#  _Object(key='inactive/divergence_test/div_test_drift.csv'),
#  _Object(key='inactive/divergence_test/div_test_train.csv'),
#  _Object(key='inactive/empty_000.csv'),
#  _Object(key='inactive/example8.txt'),
#  _Object(key='inactive/example9.txt'),
#  _Object(key='inactive/gabriel/test.parquet'),
#  _Object(key='inactive/gabrieltest.csv'),
#  _Object(key='inactive/gabrieltest2.csv'),
#  _Object(key='inactive/iris.csv'),
#  _Object(key='integration-test_iris_ground_truth_1_30_2025.csv'),
#  _Object(key='joyce-test-folder/iris.py'),
#  _Object(key='modified_diabetes.csv'),
#  _Object(key='my_text_8.txt'),
#  _Object(key='parquet/driver_stats.parquet'),
#  _Object(key='prototype_pred.csv'),
#  _Object(key='redshift-data/yellow_cab.csv'),
#  _Object(key='remedy_pred.csv'),
#  _Object(key='system_tests_DO_NOT_CHANGE/content.txt'),
#  _Object(key='system_tests_DO_NOT_CHANGE/diabetes.csv'),
#  _Object(key='system_tests_TMP/put.txt'),
#  _Object(key='system_tests_TMP/upload.txt'),
#  _Object(key='test/nested-folder'),
#  _Object(key='testBytesIO_8.txt'),
#  _Object(key='testBytesIO_9.txt'),
#  _Object(key='test_gabriel'),
#  _Object(key='test_put_sdk_201dev1'),
#  _Object(key='test_s3_1.txt'),
#  _Object(key='test_s3_3.txt'),
#  _Object(key='test_s3_3_BytesIO.txt'),
#  _Object(key='test_s3_4.txt'),
#  _Object(key='test_s3_4_BytesIO.txt'),
#  _Object(key='test_s3_4_b.txt'),
#  _Object(key='test_s3_5.txt'),
#  _Object(key='test_s3_5_BytesIO.txt'),
#  _Object(key='test_s3_5_b.txt'),
#  _Object(key='test_s3_BytesIO_7.txt'),
#  _Object(key='train_divorce.csv')]
